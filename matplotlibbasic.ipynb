# %%
import matplotlib.pyplot as plt
import pandas as pd
dataset = pd.read_csv("/content/Iris(1).csv")
x = dataset.iloc[:, 1]
y = dataset.iloc[:, 2]
# x = [1, 2, 3, 4, 5, 6, 7]
# y = [50, 51, 48, 47, 42, 40, 45]
#plt.plot(x, y,
         #color = "red",
         # linestyle = "dashed", marker = "x", markerfacecolor = "blue")
# plt.scatter(x, y,
#          color = "blue",
#          linestyle = "dashed", marker = "x",)
plt.bar(x, y,
         color = "green",
         linestyle = "dashed",)
plt.ylabel("temprature")
plt.xlabel("days")
plt.title("weather report")
plt.show()
